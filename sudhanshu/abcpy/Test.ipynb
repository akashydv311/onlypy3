# %%
print("Hello, World!")
# Out:
# Hello, World!

# %%
a = 90

# %%
type(a)
# Out:
# int

# %%
b = 78

# %%
type(b)
# Out:
# int

# %%
c = a+b

# %%
type(c)
# Out:
# int

# %%
print("Sum of a and b is: ", c)
# Out:
# Sum of a and b is:  168

# %%
name = "Akash Yadav"

# %%
type(name)
# Out:
# str

# %%
x = 90.78

# %%
type(x)
# Out:
# float

# %%
d = 4+6j

# %%
type(d)
# Out:
# complex

# %%
e = True

# %%
type(e)
# Out:
# bool

# %%
True - True
# Out:
# 0

# %%
True - False
# Out:
# 1

# %%
s = "Akash"

# %%
s*3
# Out:
# 'AkashAkashAkash'

# %%
s += 3
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 s += 3
#
# TypeError: can only concatenate str (not "int") to str

# %%
type(print("hello"))
# Out:
# hello
# NoneType

# %%
'hello' * 3
# Out:
# 'hellohellohello'

# %%
print("Hello") * 3
# Out:
# Hello
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 print("Hello") * 3
#
# TypeError: unsupported operand type(s) for *: 'NoneType' and 'int'

# %%
# Input funcation

name = input("Enteryour name: ")

# %%
name
# Out:
# 'Akash'

# %%
type(input())
# Out:
# str

# %%
print("My details:")
name = input("ENter your name: ")
age = int(input("Enter you age: "))
learning = input("What's you are learning: ")
print(name, age, learning)
# Out:
# My details:
# Akash Yadav 25 AL Genralist
