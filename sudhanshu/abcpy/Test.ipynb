# %%
print("Hello, World!")
# Out:
# Hello, World!

# %%
a = 90

# %%
type(a)
# Out:
# int

# %%
b = 78

# %%
type(b)
# Out:
# int

# %%
c = a+b

# %%
type(c)
# Out:
# int

# %%
print("Sum of a and b is: ", c)
# Out:
# Sum of a and b is:  168

# %%
name = "Akash Yadav"

# %%
type(name)
# Out:
# str

# %%
x = 90.78

# %%
type(x)
# Out:
# float

# %%
d = 4+6j

# %%
type(d)
# Out:
# complex
