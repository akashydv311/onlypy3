# %% [markdown]
# <a href="https://colab.research.google.com/github/aksydv7/onlypy3/blob/main/ramkumar/Start_Python_DSA01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello, World!")
# Out:
# Hello, World!

# %% [markdown]
# # Variable names in python

# %%
akash = 10
himanshu = 20
add = akash + himanshu
print(add)
# Out:
# 30

# %%
#-a = 90   # can't be a variable name in python
_a = 90    # can be a name of variable
# +a = 90  # can't be a variable name any oprators 
# $a = 89  # can't be a varibale name of any special symble 
# 3a = 78  # variable name can't start with digits
